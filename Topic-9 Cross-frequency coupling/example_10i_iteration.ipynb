# %%
import numpy as np
import matplotlib.pyplot as plt

base = (1+2.3025/1024*1j)

K=10000
res = np.zeros([K,1], dtype=complex)
for k in np.arange(K):
    res[k] = x**k
plt.plot(res.real)

for k in np.arange(1001):
    if np.mod(k,50)==0:
        print(k, res[k])
# Out:
# 0 [1.+0.j]
# 50 [0.99381239+0.11220406j]
# 100 [0.97507333+0.22301957j]
# 150 [0.94401626+0.3310468j]
# 200 [0.90103026+0.43492087j]
# 250 [0.84665515+0.533329j]
# 300 [0.78157471+0.62502712j]
# 350 [0.70660805+0.70885555j]
# 400 [0.62269937+0.78375372j]
# 450 [0.530906+0.84877356j]
# 500 [0.43238513+0.90309149j]
# 550 [0.32837917+0.94601889j]
# 600 [0.22020013+0.97701077j]
# 650 [0.10921304+0.99567276j]
# 700 [-0.00318125+1.00176608j]
# 750 [-0.11556379+0.9952106j]
# 800 [-0.22651539+0.9760859j]
# 850 [-0.3346346+0.94463032j]
# 900 [-0.43855537+0.90123796j]
# 950 [-0.53696432+0.84645376j]
# 1000 [-0.62861735+0.78096666j]
